# %% [markdown]
# # Session 2.1
# ## Linear regression---introduction
# - Regression is a statistical analysis process for determining the relationship between independent and dependent variables
# - Basically, regression is what is commonly referred to as 'fitting a line to the data'
# - Here's an example with some artificially generated data
#     - Data is generated according to the function $y = \beta_{0} + \beta_{1}x + \beta_{2}x^{2} + \beta_{3}x^{3} + \epsilon$, where $\epsilon$ is a random variable drawn from the normal distribution representing measurement error/noise
#     - The objective is to find the model parameters $\vec{\beta}=\left(\beta_{0}, \beta_{1}, \beta_{2}, \beta_{3}\right)$ that fit the data best

# %% [markdown]
# ##### Create a random model, sample data with errors, fit a model to the data

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model


# Independent variable measurements; no error
N = 25   # Number of measurements/samples
xs = 2*np.random.rand(N)

# Dependent variable measurements w/ error
beta_0 = np.random.normal(size = 1)[0]-0.5        # beta_0 is y-intercept
beta_1 = np.random.normal(size = 1)[0]-0.5        # beta_1 is linear term
beta_2 = np.random.normal(size = 1)[0]-0.5        # beta_2 is quadratic term
beta_3 = np.random.normal(size = 1)[0]-0.5        # beta_3 is cubic term
ys_true = beta_0 + beta_1*xs + beta_2*xs**2 + beta_3*xs**3

errors = 1*np.random.normal(size = N)

ys_measured = ys_true + errors    # Measured data is true data plus error measurement


# Create and train a model to fit the data using sklearn.linear_model.LinearRegression()
X = np.hstack((xs.reshape(-1,1), (xs**2).reshape(-1,1), (xs**3).reshape(-1,1)))
model = sklearn.linear_model.LinearRegression()
model.fit(X, ys_measured)


# Print real vs determined coefficients
betas = [beta_0, beta_1, beta_2, beta_3]
print('actual', 'determined\n')
print(model.intercept_, beta_0)
for i in range(len(model.coef_)):
    print(betas[i+1], model.coef_[i])
# Out:
# actual determined
#
# -0.223440000759 -1.64669008423
# 0.305365139927 -6.97506240446
# 0.836779451605 8.09051507621
# -0.299795500736 -2.40388565792

# %% [markdown]
# ##### Plot data and model fits

# %%
# Create the figure
fig = plt.figure(figsize = (8,6))

# Plot the data
plt.scatter(xs, ys_measured, s = 100, zorder = 2, label = 'data')

# Plot the generating function
temp_xs = np.linspace(xs.min(), xs.max(), 100).reshape(-1,1)
y_trues = beta_0 + beta_1*temp_xs + beta_2 * temp_xs**2 + beta_3 * temp_xs**3
plt.plot(temp_xs, y_trues, ls = '--', lw = 3, c = 'gray', zorder = 1, label = 'true')

# Plot the model/predictions
temp_xs = np.linspace(xs.min(), xs.max(), 100).reshape(-1,1)
temp_X = np.hstack((temp_xs, temp_xs**2, temp_xs**3))
y_predictions = model.predict(temp_X)
plt.plot(temp_xs, y_predictions, ls = '--', lw = 3, c = 'k', zorder = 1, label = 'model')

# Plot the residuals
for i in range(N):
    y_predicted = model.predict(np.array([xs[i], xs[i]**2, xs[i]**3]).reshape(1,3))
    plt.plot([xs[i], xs[i]], [y_predicted, ys_measured[i]], color = 'red', ls = ':', lw = 3)
plt.plot([],[], color = 'red', ls = ':', lw = 3, label = 'residuals')

plt.xlabel('x', size = 16)
plt.ylabel('y', size = 16)
plt.grid()
plt.legend(loc = 'lower right')

fig.tight_layout()


# plt.savefig('./images/lr_plot.png', dpi = 100)

plt.show()

# %% [markdown]
# - Notice that we fit a non-linear function using *linear regression*;
# - The *linear* part of 'linear regression' is a bit of a misnomer; linear in this case means that the output $y$ is a linear function of the *model paramters*; not the independent variables
# - Let's dive in to figuring out how linear regression works, and then use it on a real data set

# %% [markdown]
# ## The goal of linear regression
# - The goal of linear regression is to create and train models that make accurate predictions about the output values of new input data
# - Basically, we want to fit a line to data so that we can make predictions on new data
# - In a regression problem we start with some data that we know the inputs $\vec{x}^{i}$ and outputs $y^{i}$ for; we wish to train a model with parameters $\vec{\beta}$ to make output predictions $\hat{y}^{i}_{new}$ on new input data $\vec{x}^{i}_{\mathrm{new}}$
# - Example: Predicting house prices
#     - $\vec{x}^{i}$:
#         - $\left(1\times K\right)$ row vector
#         - $ \vec{x}^{i}=\left(\begin{array}{cccc}
#             x_{0}^{0} & x_{1}^{0} & \ldots & x_{K}^{0} \\
#             \end{array}\right)
#           $
#         - $x^{i}_{j}$ corresponds to a feature j for house i
#         - Features could include square footage, year built, etc.
#         - These vectors are the input for our model; for each house, we have one vector of features
#     - $\vec{\beta}$:
#         - $\left(K\times1\right)$ column vector
#         - $ \vec{\beta}=\left(\begin{array}{c}\beta_{0} \\ \beta_{1} \\ \vdots \\ \beta_{K}\end{array}\right) $
#         - $\beta$ is a column vector of model parameters
#         - Each feature $j$ has one parameter $\beta_{j}$, which indicates how significantly feature $j$ affects the price of the home
#     - $y^{i}$:
#         - This is the price of house $i$ in our training set
#     - $\hat{y}^{i}$:
#         - This is the *predicted* price of house $i$ in our training set given model parameters $\vec{\beta}$
#     - Making model predictions
#         - Our model maps input $\vec{x}^{i}$ to predicted output $\hat{y}^{i}$ via $$\begin{align} \vec{x}^{i}\vec{\beta}&=\hat{y}^{i} \\ x_{0}^{i}\beta_{0}+x_{1}^{i}\beta_{1}+x_{2}^{i}\beta_{2}+...+x_{K}^{i}\beta_{K}&=\hat{y}^{i} \end{align}$$
#         - If $y$ is house price and $x_{j}$ is square footage, $\beta_{j}$ tells us how much our home price increases if we increase the square footage
#
#
# ### How do we train the model?
# $\DeclareMathOperator*{\argminB}{argmin}$
# - To make accurate predictions, we need to find the best model parameters $\vec{\beta}$; how do we do this?
# - First, we make predictions $\hat{y}^{i}$ on input data $\vec{x}^{i}$ that we already know the answer $y^{i}$ for, according to the equation above
# - Then, we calculate something called the 'cost function' for the data, which is a measure of the difference between the predicted output and the actual output across all data points
# - For linear regression, we can use the 'residual sum of squares' (** RSS **) cost function
# - The optimum model is found by minimizing the RSS with respect to the model's parameters $\vec{\beta}$
# - $$ \begin{align} \mathrm{RSS}&=\sum_{i=0}^{N-1}\left(\hat{y}^{i}-y^{i}\right)^{2} \\
# \mathrm{RSS}\left(\vec{\beta}\right)&=\sum_{i=0}^{N-1}\left(\vec{x}^{i}\vec{\beta}-y^{i}\right)^{2} \\
# \vec{\beta}^{*}&=\argminB_{\vec{\beta}}~\mathrm{RSS}\left(\vec{\beta}\right)\end{align}$$
# - Basically, find the parameter vector $\vec{\beta}^{*}$ that minimizes the sum of squared residuals (red dotted lines below)
#
#
# ![lr_plot](./images/lr_plot.png)
#
# - How do we find the minimum of a function?
# - One approach is calculus: at the minimum, the derivative of the function is equal to zero; we could analytically solve for the location of the zero with pen-and-paper mathematics
# - Another approach would be to *numerically* find the minimum of the function using an approach called ** gradient descent **
#
# ### Gradient descent
# - Imagine what the residual sum of squares function $\mathrm{RSS}\left(\vec{\beta}\right)$ looks like
# - At the optimum position $\vec{\beta}^{*}$ the $\mathrm{RSS}$ is at its minimum value
# - Very far away from $\vec{\beta}^{*}$ the $\mathrm{RSS}$ is large; for bad model parameters the error is huge
# - The topology of $\mathrm{RSS}$ is like a rounded-bowl with lowest position $\vec{\beta}^{*}$
# - Using ** gradient descent ** we start at some arbitrary position---usually along the slope of the bowl---and slowly walk downhill until we find the lowest spot; once there, we stop, and declare our position $\vec{\beta}^{*}$ to be the optimum
# ![gradient descent](./images/gradient_descent.png)
#
# ### Scikit-learn
# - We could code gradient descent ourselves, but Python already has a package called scikit-learn that does the work for us; no need to reinvent the wheel
# - The example at the beginning of this session used scikit-learn to perform linear regression on an artificial data set
# - Usage:
#     - Put all of the input data into a numpy matrix `X_train` that has $N$ rows (number of samples) and $K$ columns (number of features)
#     - Put the outputs into a numpy column vector `y_train` that has $N$ elements, one for each sample
#     - ** Create an empty linear regression model ** using
#         - `model = sklearn.linear_model.LinearRegression()`
#     - ** Fit the model** using
#         - `model.fit(X_train, y_train)`
#     - To ** make predictions on new input data `X_test` **, use
#         - `y_test_predicted = model.predict(X_test)`
#     - Simple!

# %% [markdown]
# ## <font color="red">Exercise: Using linear regression to predict house prices (30 minutes)</font>
# 1. The file './data/train_reduced.csv' contains data on houses and their sale price; load the file into a numpy.ndarray
#     - Caution: You probably need to tell the function you use to load the data to ignore the first line of the file, which is the feature header
# 2. Create a list of the feature names
#     - Hint: Use open() and the csv.reader() object to extract the first row from the file
# 3. Write a function that returns the correct column of a given feature name; `raise` a `ValueError()` if the feature is not found
# 4. Put 80% of the rows into a training set and the remainder in a test set
# 5. Separate the inputs (the X's) from the output (the y column, 'SalePrice')
# 6. Create a linear regression model using `sklearn.linear_model.LinearRegression()`
# 7. Fit the model on the training data
# 8. Predict the sale price for the X training data
# 9. Once you've completed the above steps, complete the follow up exercises/questions

# %% [markdown]
# ##### Begin solution below!

# %%
##########################
# Insert solution below! #
##########################

# imports
import csv
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model



# Print columns to see which column is output
file_path = './data/house/train_reduced.csv'
with open(file_path, 'r') as file_handle:
    file_reader = csv.reader(file_handle, delimiter = '\t')
    header = next(file_reader)
print(header)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
features = header[:-1]

def GetColumnIndex(feature):
    for i in range(len(features)):
        if feature == features[i]:
            return i
        
    raise ValueError('Could not find column' + str(feature_name))

# %%
output_column = -1

# Load the data
file_path = './data/house/train_reduced.csv'
all_data = np.genfromtxt(file_path, delimiter = '\t', skip_header = 1)

# Standardize the data
#for i in range(all_data.shape[1]):
#    all_data[:,i] = (all_data[:,i] - np.mean(all_data[:,i]))/np.std(all_data[:,i])


# Split into train and test data
N_total = all_data.shape[0]
N_train = int(0.8*N_total)
N_test = N_total - N_train

train_data = all_data[:N_train,:]
test_data = all_data[N_train:,:]

# Split the data into X (inputs) and y (outputs)
X_train = train_data[:,:-1]
y_train = train_data[:,-1]

X_test = test_data[:,:-1]
y_test = test_data[:,-1]

# Create an empty linear regression model
model = sklearn.linear_model.LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test data
y_test_predicted = model.predict(X_test)

# %% [markdown]
# ##### <font color="red">Print a list of the features and their associated model coefficients</font>

# %%
##########################
# Insert solution below! #
##########################

for i in range(len(features)):
    print(features[i], model.coef_[i])
# Out:
# MSSubClass -115.060979009
# LotFrontage 124.961616736
# LotArea 0.48503961483
# OverallQual 14774.4546187
# OverallCond 4208.05009822
# YearBuilt 266.175628817
# YearRemodAdd 223.748920583
# MasVnrArea 30.0642254092
# BsmtFinSF2 -15.3837345129
# BsmtUnfSF -17.1231800321
# TotalBsmtSF 38.1797394123
# 1stFlrSF 14.1596225208
# 2ndFlrSF 18.6564638544
# LowQualFinSF -1.40734652138
# GrLivArea 31.4087398527
# BsmtFullBath 2856.25650033
# BsmtHalfBath -1006.14003939
# FullBath 2199.8968566
# HalfBath -342.748199657
# BedroomAbvGr -13385.0655138
# KitchenAbvGr -16678.2119608
# TotRmsAbvGrd 7472.01921989
# Fireplaces 3122.33894291
# GarageYrBlt 146.520773326
# GarageCars 162.558798251
# GarageArea 25.0395894289
# WoodDeckSF 14.8229717139
# OpenPorchSF -11.3968156443
# EnclosedPorch 12.7405059285
# 3SsnPorch -28.0523511548
# ScreenPorch 57.4716658714
# PoolArea -46.1662187466
# MiscVal -0.444707441448
# MoSold -463.099188133
# YrSold -850.30086729

# %% [markdown]
# ##### <font color="red">Plot a histogram of the sale prices in the training set with 20 bins</font>

# %%
##########################
# Insert solution below! #
##########################

plt.hist(y_train, bins = 20)
plt.show()

# %% [markdown]
# ##### <font color="red">Determine the average, maximum, and minimum sale prices of the training data set</font>

# %%
##########################
# Insert solution below! #
##########################

print('mean = ', np.mean(y_train))
print('max = ', np.max(y_train))
print('min = ', np.min(y_train))
# Out:
# mean =  180590.277397
# max =  755000.0
# min =  34900.0

# %% [markdown]
# ##### <font color="red">Determine the average, maximum, and minimum square footages of the houses in the training set</font>

# %%
##########################
# Insert solution below! #
##########################

i = GetColumnIndex('GrLivArea')
sq_footage = X_train[:,i]

print('mean = ', np.mean(sq_footage))
print('max = ', np.max(sq_footage))
print('min = ', np.min(sq_footage))
# Out:
# mean =  1502.07705479
# max =  4676.0
# min =  334.0

# %% [markdown]
# ##### <font color="red">Plot 'GrLivArea' vs 'SalePrice' for the test data and test predictions. Are the variables correlated?</font>

# %%
##########################
# Insert solution below! #
##########################

ix = GetColumnIndex('GrLivArea')

# Make plot
fig = plt.figure(figsize = (8,6))
plt.scatter(X_test[:,ix], y_test, label = 'test')
plt.scatter(X_test[:,ix], y_test_predicted, label = 'test predicted')

plt.xlabel('GrLivArea', size = 18)
plt.ylabel('SalePrice', size = 18)

plt.grid()
plt.tick_params(labelsize = 18)
plt.legend(loc = 'upper left', fontsize = 18)

plt.show()

# %% [markdown]
# ##### <font color="red">Plot 'GrLivArea' vs 'SalePrice' for the test data and test predictions. Are the variables correlated?</font>

# %%
##########################
# Insert solution below! #
##########################

ix = GetColumnIndex('BsmtUnfSF')

# Make plot
fig = plt.figure(figsize = (8,6))
plt.scatter(X_test[:,ix], y_test, label = 'test')
plt.scatter(X_test[:,ix], y_test_predicted, label = 'test predicted')

plt.xlabel('GrLivArea', size = 18)
plt.ylabel('SalePrice', size = 18)

plt.grid()
plt.tick_params(labelsize = 18)
plt.legend(loc = 'upper left', fontsize = 18)

plt.show()

# %% [markdown]
# ##### <font color="red">Calculate the root mean squared error 'RMSE' of the test predictions
#
# The RMSE is given by $$ \mathrm{RMSE}=\sqrt{\frac{\mathrm{RSS}}{N}}, $$ which represents the standard deviation of the residuals, a good measure of how far off our predictions are</font>

# %%
##########################
# Insert solution below! #
##########################

RSS = 0
for i in range(N_test):
    RSS = RSS + (y_test_predicted[i] - y_test[i])**2
RSS = RSS/N_test
RMSE = np.sqrt(RSS)
print(RMSE)
# Out:
# 49835.2366482

# %% [markdown]
# ### Summary
# - Linear regression is a technique for building models that can be trained on known data to make predictions for unknown data
# - 'Training' comes down to minimizing the sample 'Residual Sum of Squares' (RSS) with respect to the model parameters $\beta$
# - The RSS function can be minimized analytically (set $\nabla_{\vec{\beta}}RSS=0)$, or numerically, using for instance gradient descent
# - The `scikit-learn` Python package can be used to automatically create, train, and make predictions from models
# - In the next session we'll discuss logistic regression, a regression technique that can be used to make classification predictions
